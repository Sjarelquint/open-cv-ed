# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.92 🚀 Python-3.10.11 torch-2.0.0+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/107.7 GB disk)

# %%
import os
from PIL import Image
from IPython.display import display, clear_output, Image

# %%
# !yolo predict model=yolov8n.pt source='/content/goalkeeper.jpg' show=True
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 40.3MB/s]
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.92 🚀 Python-3.10.11 torch-2.0.0+cu118 CPU
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/goalkeeper.jpg: 384x640 2 persons, 1 sports ball, 335.8ms
# Speed: 18.1ms preprocess, 335.8ms inference, 28.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
Image(filename='runs/detect/predict/goalkeeper.jpg')

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("machine-learning-n7j7l").project("lfw-ethnicity")
dataset = project.version(1).download("folder")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.6 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=68105d89f5640ee51f4ad49c15eb0d91755f71ad9beaeb593371207d275739f0
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %%
DATA_DIR = '/content/LFW-Ethnicity-1'

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n-cls.pt")  # load a pretained model

# Use the model
results = model.train(data=DATA_DIR, epochs=1, imgsz=256)  # train the model
# Out:
# Ultralytics YOLOv8.0.92 🚀 Python-3.10.11 torch-2.0.0+cu118 CPU
# ...

# %%
Image('/content/runs/classify/train/results.png')
